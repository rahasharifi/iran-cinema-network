# %%
import networkx as nx
import pandas as pd

# %%
df_pairs = pd.read_parquet('../data/processed/collaboration_pairs.parquet')
print(df_pairs.shape)
# Out:
# (301594, 6)

# %%
G = nx.Graph()

for _, row in df_pairs.iterrows():
    if G.has_edge(row['person1'], row['person2']):
        G[row['person1']][row['person2']]['weight'] += row['weight']
    else:
        G.add_edge(row['person1'], row['person2'], weight=row['weight'])

print("تعداد گره‌ها (افراد):", G.number_of_nodes())
print("تعداد یال‌ها (روابط همکاری):", G.number_of_edges())
# Out:
# تعداد گره‌ها (افراد): 15716
# تعداد یال‌ها (روابط همکاری): 258915

# %%
# Network Denisty
density = nx.density(G)
print("Density:", density)

# Connected Components
components = list(nx.connected_components(G))
components_sorted = sorted(components, key=len, reverse=True)
print("تعداد اجزای همبند:", len(components))
print("اندازه‌ی بزرگ‌ترین جزء (Giant Component):", len(components_sorted[0]))
print("درصد از کل شبکه:", len(components_sorted[0]) / G.number_of_nodes())
# Out:
# Density: 0.0020966734789085975
# تعداد اجزای همبند: 241
# اندازه‌ی بزرگ‌ترین جزء (Giant Component): 14305
# درصد از کل شبکه: 0.9102188852125223

# %%
# Degree و Weighted Degree
degree_dict = dict(G.degree())
weighted_degree_dict = dict(G.degree(weight='weight'))

top_degree = sorted(degree_dict.items(), key=lambda x: x[1], reverse=True)[:10]
print("پرارتباط‌ترین افراد (Degree):", top_degree)
# Out:
# پرارتباط‌ترین افراد (Degree): [('nm2465620', 829), ('nm1714957', 772), ('nm1286513', 766), ('nm5747379', 761), ('nm0451571', 742), ('nm0707308', 736), ('nm2932763', 720), ('nm0008206', 712), ('nm2114785', 708), ('nm1471776', 677)]

# %%
# Betweenness Centrality (روی Giant Component، چون محاسبه‌ش سنگینه)
giant = G.subgraph(components_sorted[0])
betweenness = nx.betweenness_centrality(giant, weight='weight')
top_betweenness = sorted(betweenness.items(), key=lambda x: x[1], reverse=True)[:10]
print("بیشترین نقش Bridge (Betweenness):", top_betweenness)

# %%
pip install python-louvain --break-system-packages
# Out:
# Collecting python-louvain
#   Downloading python-louvain-0.16.tar.gz (204 kB)
#      ---------------------------------------- 0.0/204.6 kB ? eta -:--:--
#      ------ --------------------------------- 30.7/204.6 kB ? eta -:--:--
#      ----------- ------------------------- 61.4/204.6 kB 825.8 kB/s eta 0:00:01
#      ------------------- ---------------- 112.6/204.6 kB 819.2 kB/s eta 0:00:01
#      ---------------------------------- - 194.6/204.6 kB 787.7 kB/s eta 0:00:01
#      ------------------------------------ 204.6/204.6 kB 691.8 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: networkx in c:\users\rahas\appdata\local\programs\python\python311\lib\site-packages (from python-louvain) (3.6.1)
# Requirement already satisfied: numpy in c:\users\rahas\appdata\local\programs\python\python311\lib\site-packages (from python-louvain) (2.1.2)
# Building wheels for collected packages: python-louvain
#   Building wheel for python-louvain (pyproject.toml): started
#   Building wheel for python-louvain (pyproject.toml): finished with status 'done'
#   Created wheel for python-louvain: filename=python_louvain-0.16-py3-none-any.whl size=9473 sha256=f22be769edc67757fc76b68523f718f5ff0fe9f15455d856a814c9b1af46acd1
#   Stored in directory: c:\users\rahas\appdata\local\pip\cache\wheels\11\c1\e7\f62a211c636275e2da798bf0c307a3ae79aeddaf2524a03ce4
# Successfully built python-louvain
# Installing collected packages: python-louvain
# Successfully installed python-louvain-0.16
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import community as community_louvain

partition = community_louvain.best_partition(giant, weight='weight')
print("تعداد Communityها:", len(set(partition.values())))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import community as community_louvain
# ----> 3 partition = community_louvain.best_partition(giant, weight='weight')
#       4 print("تعداد Communityها:", len(set(partition.values())))
#
# NameError: name 'giant' is not defined
