# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Exploring "title.basics.tsv.gz"

# %%
df_basics = pd.read_csv('../data/raw/title.basics.tsv.gz', sep='\t', low_memory=False)

# %%
df_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              5  Animation,Comedy,Romance
# 3        0      1892      \N             12           Animation,Short
# 4        0      1893      \N              1                     Short

# %%
df_basics.shape
# Out:
# (12672946, 9)

# %% [markdown]
# ## Exploring "title.crew.tsv.gz"

# %%
df_crew = pd.read_csv('../data/raw/title.crew.tsv.gz', sep='\t', low_memory=False)

# %%
df_crew.head()
# Out:
#       tconst  directors    writers
# 0  tt0000001  nm0005690         \N
# 1  tt0000002  nm0721526         \N
# 2  tt0000003  nm0721526  nm0721526
# 3  tt0000004  nm0721526         \N
# 4  tt0000005  nm0005690         \N

# %% [markdown]
# ## Exploring "title.akas.tsv.gz"

# %%
df_akas = pd.read_csv('../data/raw/title.akas.tsv.gz', sep='\t', low_memory=False)

# %%
df_akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Carmencita     \N       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3                 Carmencita     US       \N
# 3  tt0000001         4  Carmencita - spanyol tánc     HU       \N
# 4  tt0000001         5                 Καρμενσίτα     GR       \N
#
#          types     attributes  isOriginalTitle
# 0     original             \N                1
# 1           \N  literal title                0
# 2  imdbDisplay             \N                0
# 3  imdbDisplay             \N                0
# 4  imdbDisplay             \N                0

# %% [markdown]
# ## Exploring "title.principals.tsv.gz"

# %%
df_principals = pd.read_csv('../data/raw/title.principals.tsv.gz', sep='\t', low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_principals = pd.read_csv('../data/raw/title.principals.tsv.gz', sep='\t', low_memory=False)
#
# ...

# %%
df_principals.head()
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0005690         producer                 producer
# 3  tt0000001         4  nm0374658  cinematographer  director of photography
# 4  tt0000002         1  nm0721526         director                       \N
#
#   characters
# 0   ["Self"]
# 1         \N
# 2         \N
# 3         \N
# 4         \N

# %% [markdown]
# ## Exploring "title.ratings.tsv.gz"

# %%
df_ratings = pd.read_csv('../data/raw/title.ratings.tsv.gz', sep='\t', low_memory=False, nrows=10000)

# %%
df_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2219
# 1  tt0000002            5.4       323
# 2  tt0000003            6.4      2362
# 3  tt0000004            5.1       194
# 4  tt0000005            6.2      3075

# %% [markdown]
# ## Exploring "name.basics.tsv.gz"

# %%
df_names = pd.read_csv('../data/raw/name.basics.tsv.gz', sep='\t', low_memory=False, nrows=10000)

# %%
df_names.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934      2025
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                    primaryProfession                           knownForTitles
# 0       actor,miscellaneous,producer  tt0072308,tt0050419,tt0027125,tt0025164
# 1   actress,miscellaneous,soundtrack  tt0037382,tt0075213,tt0038355,tt0117057
# 2  actress,music_department,producer  tt0057345,tt0049189,tt0056404,tt0054452
# 3      actor,writer,music_department  tt0072562,tt0077975,tt0080455,tt0078723
# 4              writer,director,actor  tt0050986,tt0083922,tt0069467,tt0050976

# %% [markdown]
# ## Find Irainian Candidates

# %%
iran_titles = df_akas[df_akas['region'] == 'IR']['titleId'].unique()

# %%
print(len(iran_titles))
# Out:
# 18950

# %%
iran_basics = df_basics[df_basics['tconst'].isin(iran_titles)]
iran_basics['titleType'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 iran_basics = df_basics[df_basics['tconst'].isin(iran_titles)]
#       2 iran_basics['titleType'].value_counts()
#
# NameError: name 'iran_titles' is not defined

# %%
selected_types = ['movie', 'tvSeries', 'tvMovie', 'tvMiniSeries']
iranian_tconst = df_basics[df_basics['tconst'].isin(iran_titles) & df_basics['titleType'].isin(selected_types)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 selected_types = ['movie', 'tvSeries', 'tvMovie', 'tvMiniSeries']
# ----> 2 iranian_tconst = df_basics[df_basics['tconst'].isin(iran_titles) & df_basics['titleType'].isin(selected_types)]
#
# NameError: name 'iran_titles' is not defined
