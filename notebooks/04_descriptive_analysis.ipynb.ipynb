# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/processed/iran_cinema_clean.parquet')

# سؤال ۱: روند تولید در طول زمان
films_per_year = df.drop_duplicates('tconst').groupby('startYear').size()
films_per_year.plot(kind='line', title='روند تولید آثار سینمای ایران')
